# %%
mkdir YOLOv9-Flask-WebApp

# %%
cd YOLOv9-Flask-WebApp
# Out:
# /content/YOLOv9-Flask-WebApp

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 781, done.
# remote: Total 781 (delta 0), reused 0 (delta 0), pack-reused 781 (from 1)
# Receiving objects: 100% (781/781), 3.27 MiB | 5.00 MiB/s, done.
# Resolving deltas: 100% (330/330), done.

# %%
cd yolov9/
# Out:
# /content/YOLOv9-Flask-WebApp/yolov9

# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.9 MB/s eta 0:00:00
# ...

# %%
# !pip install torch

# %%
import os

print(os.path.exists("Resource/image1.jpeg.png"))
print(os.path.exists("Weights/yolov9c.pt"))
# Out:
# True
# True

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.9 MB/s eta 0:00:00
# ...

# %%
# !python detection.py

# %%
pip install ultralytics

# %%
from flask import Flask

# %%
# !pip install flask-wtf

# %%
# !pip install flask flask-wtf flask-bootstrap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.4/456.4 kB 36.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.5/152.5 kB 20.2 MB/s eta 0:00:00
# ...
#   Created wheel for flask-bootstrap: filename=Flask_Bootstrap-3.3.7.1-py3-none-any.whl size=460121 sha256=7e84e8b01b524350af9433512fbba5374a5698419160a761c5d6f64193489e52
#   Stored in directory: /root/.cache/pip/wheels/6d/f7/48/c73d278a3ad5edb4754488c1c22a945d947e14ecdb042d198e
# ...
#   Created wheel for visitor: filename=visitor-0.1.3-py3-none-any.whl size=3926 sha256=80da7362e13c275e19ec4a9a730e7333b6aa47bd53210e9b657d5b4cc545ffe4
#   Stored in directory: /root/.cache/pip/wheels/43/cd/2c/1ab9dfe7ed35891f3775f1d2a79159ff1903725461d44519d2
# Successfully built flask-bootstrap visitor
# ...

# %%
# 1️⃣ Install pyngrok
# !pip install pyngrok flask flask-wtf

# 2️⃣ Import modules
from flask import Flask, Response
from threading import Thread
from pyngrok import ngrok
import cv2

# 3️⃣ Flask app
app = Flask(__name__)

def generate_frames(path):
    cap = cv2.VideoCapture(path)
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        ret, buffer = cv2.imencode(".jpg", frame)
        frame_bytes = buffer.tobytes()
        yield (b'--frame\r\n'
               b'Content-Type: image/jpeg\r\n\r\n' + frame_bytes + b'\r\n')

@app.route("/video_feed")
def video_feed():
    return Response(generate_frames("Resource/video1.mp4"),
                    mimetype="multipart/x-mixed-replace; boundary=frame")

# 4️⃣ Open ngrok tunnel
public_url = ngrok.connect(5000)
print("🚀 Public URL:", public_url)

# 5️⃣ Run Flask in a thread
def run_app():
    app.run(port=5000)

Thread(target=run_app).start()
# Out:
# ...
# ERROR:pyngrok.process.ngrok:t=2026-03-13T02:56:20+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-03-13T02:56:20+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_6817/2933426032.py in <cell line: 0>()
#      28
#      29 # 4️⃣ Open ngrok tunnel
# ...

# %%
# !python flaskApp.py
# Out:
#  * Serving Flask app 'flaskApp'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 360-015-201

# %%
from pathlib import Path
import os

# Set your YOLO project folder
ROOT = Path("/content/YOLOv9-Flask-WebApp/yolov9")  # <- adjust if your folder is different

# Make sure ROOT exists
assert ROOT.exists(), f"Folder {ROOT} does not exist"

# %%
# !yolo task=detect mode=predict model="/content/YOLOv9-Flask-WebApp/yolov9/yolov8n.pt"  data="/content/YOLOv9-Flask-WebApp/yolov9/Resource/video1.mp4" save=True save_txt=True
# Out:
# WARNING ⚠️ 'source' argument is missing. Using default 'source=/usr/local/lib/python3.12/dist-packages/ultralytics/assets'.
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/2 /usr/local/lib/python3.12/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 54.6ms
# image 2/2 /usr/local/lib/python3.12/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 49.1ms
# Speed: 3.4ms preprocess, 51.8ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/YOLOv9-Flask-WebApp/yolov9/runs/detect/predict5
# 2 labels saved to /content/YOLOv9-Flask-WebApp/yolov9/runs/detect/predict5/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
pip install flask

# %%
import os

# %%
from flask import Flask, render_template, request, Response, jsonify

# %%
import cv2

# %%
from detect import run

# %%
#initialize the flask application

app = Flask(__name__)

# %%
#configure a secret key
app.config["SECRET_KEY"] = "Hasen"

# %%
cd YOLOv9-Flsk-WebApp
# Out:
# [Errno 2] No such file or directory: 'YOLOv9-Flsk-WebApp'
# /content/YOLOv9-Flask-WebApp/yolov9

# %%
os.chdir("/content/YOLOv9-Flask-WebApp/yolov9")

# %%
# %pwd
# Out:
# '/content/YOLOv9-Flask-WebApp/yolov9'

# %%
#store the inout files uploaded in the application
app.config["UPLOAD_FOLDER"] = "static/files"

# %%
def generate_frames(path):
  yolov9_output = run(path)
  for im0, frameRate, frameShape, totalDetection in yolov9_output:
    ret, buffer = cv2.imencode("jpg", im0)
    frame = buffer.tobytes()
    yield (b"frame\r\n" b"content-Type: image/jpeg\r\n\r\n" + frame + b"\r\n")
